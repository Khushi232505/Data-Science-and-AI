# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi232505/Data-Science-and-AI/blob/main/Module_3_Statistics_and_Mathmatics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***2. Median***
#
# Median is the middle value after sorting the data
#
# if there are:
# 1. Odd observations--> Middle value
# 2. Even obseravtions --> Average of middle values

# %%
import pandas as pd
import numpy as np


data = {
    "Employee": [
        "A", "B", "C", "D", "E",
        "F", "G", "H", "I", "J"
    ],
    "Age": [
        22, 25, 28, 30, 35,
        40, 32, 29, 45, 38
    ],
    "Salary": [
        25000, 32000, 40000, 42000, 50000,
        62000, 47000, 43000, 75000, 68000
    ],
    "Experience": [
        1, 2, 4, 5, 8,
        12, 6, 5, 18, 15
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display Dataset
print("=" * 50)
print("Employee Dataset")
print("=" * 50)
print(df)

# ==========================================
# Median of Individual Columns
# ==========================================

print("\nMedian of Age:")
print(df["Age"].median())

print("\nMedian of Salary:")
print(df["Salary"].median())

print("\nMedian of Experience:")
print(df["Experience"].median())

# ==========================================
# Median of All Numerical Columns
# ==========================================

print("\n" + "=" * 50)
print("Median of All Numerical Columns")
print("=" * 50)

print(df.median(numeric_only=True))
# Out:
# ...
# Employee Dataset
# ...
#   Employee  Age  Salary  Experience
# 0        A   22   25000           1
# 1        B   25   32000           2
# 2        C   28   40000           4
# 3        D   30   42000           5
# 4        E   35   50000           8
# 5        F   40   62000          12
# 6        G   32   47000           6
# 7        H   29   43000           5
# 8        I   45   75000          18
# 9        J   38   68000          15
#
# Median of Age:
# 31.0
#
# Median of Salary:
# 45000.0
#
# Median of Experience:
# 5.5
#
# ...
# Median of All Numerical Columns
# ...
# Age              31.0
# Salary        45000.0
# Experience        5.5
# dtype: float64
