# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi232505/Data-Science-and-AI/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Matplotlib***
#
# It is the most popular python library used for creating data visualizations.
# It converts numerical data into meaningful charts and graphs that helps users analyze trends, patterns, and comparisons.
#
# # ***Features of Matplotlib***
#
# 1. Open source
# 2. Highly customizable
# 3. Supports 20+ chart types
# 4. Publication Quality charts
# 5. Works perfectly with Numpy and Pandas
# 6. Can save images in PNG, JPG, PDF, SVG

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# first graph
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,20,15,30,25]

plt.plot(x,y)

plt.plot() # display the graph on screen
plt.savefig('first_graph.png') #save the graph
plt.savefig('first_graph.pdf') #save the graph
plt.savefig('first_graph.jpg') #save the graph

# %%
# First Graph using Matplotlib

import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

# Create Figure
plt.figure(figsize=(8, 5))

# Plot Line Graph
plt.plot(
    x,
    y,
    marker='o',
    linestyle='-',
    linewidth=2,
    color='blue',
    label='Sales'
)

# Title and Labels
plt.title("First Line Graph", fontsize=16)
plt.xlabel("X Values", fontsize=12)
plt.ylabel("Y Values", fontsize=12)


# Save the graph
plt.savefig("first_graph.png", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.jpg", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.pdf", bbox_inches="tight")

# Display the graph
plt.show()

# Close the figure
plt.close()

# %% [markdown]
# # ***Line Chart***
#
# A line chart is used to display trends or changes over a sequence of observations. It connects data using points using straight lines.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/student.csv")

plt.figure(figsize= (12,6))

plt.plot(df["G3"])

plt.show()

# %% [markdown]
# # ***Module 3 - Bar Charts***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load Dataset
df = pd.read_csv("employee_salary.csv")

# =====================================================
# 1. bar()
# =====================================================


salary_by_age = df.groupby("age")["income"].mean()

plt.figure(figsize=(10,6))
plt.bar(salary_by_age.index.astype(str), salary_by_age.values)

plt.title("Basic Bar Chart (Mean Income by Age)")
plt.xlabel("Age")
plt.ylabel("Mean Income")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# =====================================================
# 2. barh()
# =====================================================

plt.figure(figsize=(10,6))
plt.barh(salary_by_age.index.astype(str), salary_by_age.values)

plt.title("Horizontal Bar Chart (Mean Income by Age)")
plt.xlabel("Mean Income")
plt.ylabel("Age")
plt.tight_layout()
plt.show()

# =====================================================
# 3. width
# =====================================================

plt.figure(figsize=(10,6))
plt.bar(
    salary_by_age.index.astype(str),
    salary_by_age.values,
    width=0.4
)

plt.title("Bar Width Example (Mean Income by Age)")
plt.xlabel("Age")
plt.ylabel("Mean Income")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# =====================================================
# 4. color
# =====================================================

plt.figure(figsize=(10,6))

plt.bar(
    salary_by_age.index.astype(str),
    salary_by_age.values,
    color="pink"
)

plt.title("Bar Color Example (Mean Income by Age)")
plt.xlabel("Age")
plt.ylabel("Mean Income")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# =====================================================
# 5. edgecolor
# =====================================================

plt.figure(figsize=(10,6))

plt.bar(
    salary_by_age.index.astype(str),
    salary_by_age.values,
    color="skyblue",
    edgecolor="black"
)

plt.title("Edge Color Example (Mean Income by Age)")
plt.xlabel("Age")
plt.ylabel("Mean Income")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ***Employee Count Bar Chart***
#
# Display the total number of employees in each department.

# %%
import matplotlib.pyplot as plt
import pandas as pd
departments = ["HR","IT","finance","Sales","Marketing"]
employee_count = [10,15,7,12,8]
#create bar chart
plt.bar(departments, employee_count)
plt.xlabel("Department")
plt.ylabel("Employee Count")
plt.title("Employee Count by Department")
plt.show()

# %% [markdown]
# # ***Module 4 — Histogram***
#
# Dataset House Prices Dataset Topics
#
#
# *   hist()
# *  bins
# * density
# * cumulative histogram
# * transparency
#
# **Histogram**
#
# A Histogram is a graphical representation used to display the frequency distribution of continuous numerical data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset

df = pd.read_csv("/content/house_prices (1).csv", on_bad_lines='skip', engine='python')

print("DataFrame Columns:", df.columns)

# =====================================================
# 1. Basic Histogram
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(df["Price (in rupees)"]) # A histogram groups numerical data into intervals (bins) and displays the frequency.

plt.title("Basic Histogram")

plt.show()

# =====================================================
# 2. bins
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(                         # bins decides how many intervals (groups) the data is divided into.
    df["Price (in rupees)"],
    bins=20
)

plt.title("Histogram using Bins")

plt.show()

# =====================================================
# 3. density
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(
    df["Price (in rupees)"], # Instead of showing frequency, it shows the Probability Density.
    bins=20,
    density=True
)

plt.title("Density Histogram")

plt.show()

# =====================================================
# 4. cumulative histogram
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(
    df["Price (in rupees)"],  # Shows the cumulative frequency.
    bins=20,
    cumulative=True
)

plt.title("Cumulative Histogram")

plt.show()

# =====================================================
# 5. transparency (alpha)
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(
    df["Price (in rupees)"], # Transparency is controlled using the alpha parameter.
    bins=20,
    alpha=0.5
)

plt.title("Histogram using Transparency")

plt.show()
# Out:
# DataFrame Columns: Index(['Index', 'Title', 'Description', 'Amount(in rupees)',
#        'Price (in rupees)', 'location', 'Carpet Area', 'Status', 'Floor',
#        'Transaction', 'Furnishing', 'facing', 'overlooking', 'Society',
#        'Bathroom', 'Balcony', 'Car Parking', 'Ownership', 'Super Area',
#        'Dimensions', 'Plot Area'],
#       dtype='object')

# %% [markdown]
# # ***Practical 1 — House Price Distribution***
#
# Objective
#
# Visualize the distribution of house prices.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/house_prices (1).csv")
plt.figure(figsize=(12,6))
plt.hist(
    df["Price (in rupees)"], # Changed 'SalePrice' to 'Price (in rupee
    bins=30,
    color="royalblue",
    edgecolor="black"
)
plt.title("House Price Distribution")
plt.xlabel("Sale Price")
plt.ylabel("Number of Houses")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# # ***Module 5 — Scatter Plot***
#
# Dataset - Iris Dataset Topics
#
#
# * scatter()
# * size
# * color
# * alpha
# * marker
# * colormap

# %% [markdown]
# # ***Scatter Plot***
#
# A Scatter Plot is used to visualize the relationship between two numerical variables

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("/content/Iris (1).csv")

# =====================================================
# 1. Basic scatter()
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"]
)

plt.title("Basic Scatter Plot")

plt.show()

# =====================================================
# 2. size (s). # The s parameter controls the size of the markers.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    s=100
)

plt.title("Scatter Plot with Size")

plt.show()

# =====================================================
# 3. color. # Changes the color of markers.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    color="red"
)

plt.title("Scatter Plot with Color")

plt.show()

# =====================================================
# 4. alpha. # Controls the transparency.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    alpha=0.5
)

plt.title("Scatter Plot with Transparency")

plt.show()

# =====================================================
# 5. marker. # Changes the shape of the points.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    marker="^"
)

plt.title("Scatter Plot with Marker")

plt.show()

# =====================================================
# 6. colormap (cmap) # A colormap assigns colors to points based on numeric values in c.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    c=df["PetalWidthCm"],
    cmap="viridis",
    s=80
)

plt.colorbar(label="Petal Width")

plt.title("Scatter Plot with Colormap")

plt.show()

# %% [markdown]
# # ***Module 6 — Pie Charts***
#
# Dataset - Titanic Dataset Topics
#
# * pie()
# * explode
# * autopct
# * shadow
# * startangle
# * labels

# %% [markdown]
# # ***Pie Chart***
#
# A Pie Chart is used to display the proportion or percentage of each category relative
# to the whole

# %%
# =============================================
# Module 6 - Pie Charts
# Dataset : titanic.csv
# Perform All Operations Individually
# =============================================

import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("/content/titanic.csv")

# Survival Count
survival = df["Survived"].value_counts()

labels = ["Not Survived", "Survived"]

# =====================================================
# 1. Basic pie()
# =====================================================

plt.figure(figsize=(6,6))

plt.pie(survival.values)

plt.title("Basic Pie Chart")

plt.show()

# =====================================================
# 2. labels # Adds labels to each slice.
# =====================================================

plt.figure(figsize=(6,6))

plt.pie(
    survival.values,
    labels=labels
)

plt.title("Pie Chart with Labels")

plt.show()

# =====================================================
# 3. autopct # Displays percentage values on each slice.
# =====================================================

plt.figure(figsize=(6,6))

plt.pie(
    survival.values,
    labels=labels,
    autopct="%1.1f%%"
)

plt.title("Pie Chart with Percentage")

plt.show()

# =====================================================
# 4. explode # explode is used to separate one or more slices from the pie chart.
# =====================================================

explode = [0, 0.15]

plt.figure(figsize=(6,6))

plt.pie(
    survival.values,
    labels=labels,
    explode=explode,
    autopct="%1.1f%%"
)

plt.title("Pie Chart using Explode")

plt.show()

# =====================================================
# 5. shadow # Adds a shadow behind the pie chart.
# =====================================================

plt.figure(figsize=(6,6))

plt.pie(
    survival.values,
    labels=labels,
    shadow=True,
    autopct="%1.1f%%"
)

plt.title("Pie Chart with Shadow")

plt.show()

# =====================================================
# 6. startangle # Rotates the starting position of the pie chart.

# Default starting angle = 0°
# =====================================================

plt.figure(figsize=(6,6))

plt.pie(
    survival.values,
    labels=labels,
    startangle=90,
    autopct="%1.1f%%"
)

plt.title("Pie Chart using Start Angle")

plt.show()
