# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi232505/Data-Science-and-AI/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Pandas***
#
# Pandas is an open source python library used for data manipulation and data analysis.
#
# # ***Why do we use Pandas?***
#
# Pandas is used to read, clean, organize, filter, analyze, and manipulate structured data efficiently.
#
# # ***Features of Pandas : ***
#
# # ***1. Data Manipulation***
#
# Used to modify, organize, and transform data easily.
#
# # ***2. Data Analysis***
#
# Used to analyze data and extract meaningful insights.
#
# # ***3. Fast Processing***
#
# Handles large datasets efficiently with optimized performance.
#
# # ***4. Missing Value Handling***
#
# Allows easy detection and handling os missing values.
#
# # ***5. File Handling***
#
# Can read and write CSV, Excel, JSON, Sql and many other files.
#
# # ***6. Data Filtering***
#
# Used to select specific rows and columns based on conditions

# %% [markdown]
# Installation of Pandas

# %%
import pandas as pd

# %% [markdown]
# # ***Main Data Structures in Pandas***
#
# 1. series --> A series is a one-dimensional labeled array that stores a single column of data.
#
# 2. Data Frame --> A data frame is a two dimensional labeled table consisting of rows and columns

# %% [markdown]
# # ***1. Creating Series***
#
# A series is a dimensional labeled array that stores a single column of data.

# %%
import pandas as pd

marks = pd.Series([85, 90, 78, 92, 88])

print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# dtype: int64

# %% [markdown]
# Creating a series of strings

# %%
import pandas as pd
names = pd.Series(["khushi", "rosu", "sejal", "pum pum"])
print(names)
# Out:
# 0     khushi
# 1       rosu
# 2      sejal
# 3    pum pum
# dtype: object

# %% [markdown]
# # ***Custom Index***

# %%
import pandas as pd

marks = pd.Series(
    [85, 90, 78],
    index = ["Maths", "hindi", "english"]
)

print (marks)
# Out:
# Maths      85
# hindi      90
# english    78
# dtype: int64

# %% [markdown]
# # ***Series From Dictionary***

# %%
import pandas as pd

student = pd.Series({
    "name" : "khushi",
    "age" : 21,
    "city" : "lucknow"
})

print(student)
# Out:
# name     khushi
# age          21
# city    lucknow
# dtype: object

# %% [markdown]
# # ***Access Values in a Series***

# %%
import pandas as pd

marks = pd.Series([85,90,78, 92, 88])

print(marks[0])
print(marks[2])
# Out:
# 85
# 78

# %% [markdown]
# # ***Access Value Using Custom Index.***

# %%
import pandas as pd

marks = pd.Series(
    [85, 90, 78],
    index = ["Math", "Hindi", "English"]
)

print(marks["Hindi"])
# Out:
# 90

# %% [markdown]
# # ***Print Series Information***

# %%
import pandas as pd

marks = pd.Series([85, 90, 78])

print(type(marks))
print(marks.dtype)
print(marks.size)
# Out:
# <class 'pandas.core.series.Series'>
# int64
# 3

# %% [markdown]
# # ***2. Creating DataFrame***
#
# DataFrame is a two-dimensional labeled table consisting of rows and columns A DataFrame is used to store, organize, manipulate, and analyze tabular data efficiently.
#
# # ***syntax***
#
# import pandas as pd
#
# df = pd.DataFrame(data)

# %%
import pandas as pd
student = { "Name": ["Aman", "Ravi", "Priya", "Neha"],
           "Age": [20, 21, 19, 22],
            "City": ["Delhi", "Lucknow", "Noida", "Jaipur"] }
df = pd.DataFrame(student)
print(df)
# Out:
#     Name  Age     City
# 0   Aman   20    Delhi
# 1   Ravi   21  Lucknow
# 2  Priya   19    Noida
# 3   Neha   22   Jaipur

# %% [markdown]
# Create DataFrame with Custom Index

# %%
import pandas as pd
student = { "Name": ["Aman","Ravi","Priya"],
           "Marks": [85,90,78] }
df = pd.DataFrame(student, index=["S1", "S2", "S3"])
print(df)
# Out:
#      Name  Marks
# S1   Aman     85
# S2   Ravi     90
# S3  Priya     78

# %% [markdown]
# Create DataFrame from a List of Lists

# %%
import pandas as pd
data = [
     ["Aman",20,"Delhi"],
     ["Ravi", 21, "Lucknow"],
     ["Priya", 19, "Noida"]
     ]
df=pd.DataFrame(data,columns=["Name","Age","City"])
print(df)
# Out:
#     Name  Age     City
# 0   Aman   20    Delhi
# 1   Ravi   21  Lucknow
# 2  Priya   19    Noida

# %% [markdown]
# Create DataFrame from a List of Dictionaries.

# %%
import pandas as pd
data = [
     {"Name": "Aman", "Age": 20},
     {"Name": "Ravi", "Age": 21},
     {"Name": "Priya", "Age": 19}
     ]
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0   Aman   20
# 1   Ravi   21
# 2  Priya   19

# %%
import pandas as pd
df_empty = pd.DataFrame()
print(df_empty)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # ***Module 2 – Reading and Writing Data***

# %% [markdown]
# # ***1. read_csv()***
#
# read_csv() is used to read data from a CSV file into a Pandas DataFrame

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Display First Five Rows

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Display Last 5 rows

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
print(df.tail())
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# Store Using Another Variable Name

# %%
import pandas as pd
students= pd.read_csv("/content/student.csv")
print(students)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Read First 10 Rows

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
print(df.head(10))
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %% [markdown]
# Read last 10 rows

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
print(df.tail(10))
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %% [markdown]
# Read Selected Columns

# %%
import pandas as pd
df = pd.read_csv(
     "/content/student.csv",
     usecols=[ "sex", "G1", "G2" ] )
print(df)
# Out:
#     sex  G1  G2
# 0     F   5   6
# 1     F   5   5
# 2     F   7   8
# 3     F  15  14
# 4     F   6  10
# ..   ..  ..  ..
# 390   M   9   9
# 391   M  14  16
# 392   M  10   8
# 393   M  11  12
# 394   M   8   9
#
# [395 rows x 3 columns]

# %% [markdown]
# Set Index Column

# %%
import pandas as pd
df = pd.read_csv(
     "/content/student.csv",
     index_col="sex"# set sex column as index
     )
print(df)
# Out:
#     school  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# sex
# F       GP   18       U     GT3       A     4     4   at_home   teacher
# F       GP   17       U     GT3       T     1     1   at_home     other
# F       GP   15       U     LE3       T     1     1   at_home     other
# F       GP   15       U     GT3       T     4     2    health  services
# F       GP   16       U     GT3       T     3     3     other     other
# ..     ...  ...     ...     ...     ...   ...   ...       ...       ...
# M       MS   20       U     LE3       A     2     2  services  services
# M       MS   17       U     LE3       T     3     1  services  services
# M       MS   21       R     GT3       T     1     1     other     other
# M       MS   18       R     LE3       T     3     2  services     other
# M       MS   19       U     LE3       T     1     1     other   at_home
#
#      reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  \
# sex          ...
# ...
